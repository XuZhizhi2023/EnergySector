# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "svg"
import seaborn as sns
sns.set_theme(rc={"text.usetex": True})
use_tex = True
if use_tex:
    os.environ["PATH"] += os.pathsep + "D:/Applications/Texlive/2025/bin/windows/"
    plt.rcParams["text.usetex"] = True
from utils import (
    build_datasets,
    plot_norm_price,
    plot_logvol20,
)

# %% [markdown]
# XLE is an ETF that follows the macro energy sector while KOLD is an ETF that only follows natural gas price level.
#
# It can be seen that KOLD is more volatile than XLE.

# %%
tickers = ["XLE", "KOLD"]
datasets = build_datasets(tickers=tickers)
datasets["XLE"].head(3)
# Out:
#          Date  Price   Open   High    Low    Vol. Change %  norm_close_price  \
# 0  02/02/2016  53.72  54.22  54.47  53.45  25.23M   -3.33%          0.917506
# 1  02/03/2016  55.64  54.50  55.68  52.54  36.44M    3.57%          0.950299
# 2  02/04/2016  55.61  55.75  56.80  55.34  37.06M   -0.05%          0.949787
#
#      return  logvol20
# 0 -0.033291 -3.523506
# 1  0.035741 -3.481171
# 2 -0.000539 -3.520988

# %%
fig_norm_price = plot_norm_price(tickers=tickers, datasets=datasets, save_path="figures/normalized_price.png")

# %%
fig_logvol20 = plot_logvol20(tickers=tickers, datasets=datasets, save_path="figures/20_day_log_volatility.png")
